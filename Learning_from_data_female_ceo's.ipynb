# %%
# %matplotlib inline
#Imports packages needed to be used 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
#Imports the csv file for the fortune 500 companies in 2017
df = pd.read_csv('fortune_500.csv')

# %%
#Visualising the first 5 rows of the data
df.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
#Visualising the last 5 rows of the data
df.tail()
# Out:
#      Rank           Title                      Website  Employees  \
# 495   496   Michaels Cos.      http://www.michaels.com      31000
# 496   497   Toll Brothers  http://www.tollbrothers.com       4200
# 497   498           Yahoo         http://www.yahoo.com       8500
# 498   499   Vistra Energy  http://www.vistraenergy.com       4431
# 499   500  ABM Industries           http://www.abm.com     110000
#
#                          Sector                          Industry  \
# 495                   Retailing        Specialty Retailers: Other
# 496  Engineering & Construction                      Homebuilders
# 497                  Technology   Internet Services and Retailing
# 498                      Energy                            Energy
# 499           Business Services  Diversified Outsourcing Services
#
#         Hqlocation                Hqaddr     Hqcity Hqstate  ...  \
# 495     Irving, TX  8000 Bent Branch Dr.     Irving      TX  ...
# ...

# %%
#Prints the length of the data
len(df)
# Out:
# 500

# %%
#Prints all the names and types of the columns
df.dtypes
# Out:
# Rank             int64
# Title           object
# Website         object
# Employees        int64
# Sector          object
# Industry        object
# Hqlocation      object
# Hqaddr          object
# Hqcity          object
# Hqstate         object
# Hqzip            int64
# Hqtel           object
# Ceo             object
# Ceo-female      object
# Ceo-title       object
# Address         object
# Ticker          object
# Fullname        object
# Revenues         int64
# Revchange      float64
# Profits        float64
# Prftchange      object
# Assets           int64
# Totshequity    float64
# dtype: object

# %%
#Shows the rows of companies with femal CEO's
df.loc[df['Ceo-female'] == 'Yes']
# Out:
#      Rank                              Title  \
# 7       8                     General Motors
# 31     32                                IBM
# 43     44                            PepsiCo
# 55     56                    Lockheed Martin
# 58     59         Hewlett Packard Enterprise
# 80     81                             Oracle
# 89     90                   General Dynamics
# 108   109             Mondelez International
# 119   120                        Progressive
# 120   121                        Duke Energy
# 139   140                            Staples
# 156   157                         PG&E Corp.
# 184   185                Synchrony Financial
# 192   193                                CBS
# 217   218  Guardian Life Ins. Co. of America
# 218   219                        Ross Stores
# 219   220                           L Brands
# 222   223                  Reynolds American
# 245   246       Reinsurance Group of America
# 277   278               Occidental Petroleum
# ...

# %%
#Plots the number of female CEO's against males
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax =sns.countplot(x ='Ceo-female', data = df, palette = 'Blues_r')
ax.bar_label(ax.containers[0])
plt.title("Female CEO's")
plt.show()

# %%
#Plots the number of female CEO's against males by industry to see if there is a correlation
an = sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.countplot(x ='Sector', hue = 'Ceo-female', data = df)
ax.bar_label(ax.containers[0])
plt.xticks(rotation=270)
plt.title("Female CEO's by industry")
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [79], in <cell line: 7>()
#       6 plt.title("Female CEO's by industry")
#       7 for p in ax.patches:
# ----> 8     percentage = '{:.1f}%'.format(100 * p.get_height()/total)
#       9     x = p.get_x() + p.get_width()
#      10     y = p.get_height()
#
# NameError: name 'total' is not defined

# %%
#Plots the revenue change against rank to see if there is a cluster of Female CEO's
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.scatterplot(y ='Revchange', x = 'Rank', hue = 'Ceo-female', data = df)
plt.title("Revenue change by rank")
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.scatterplot(y ='Employees', x = 'Rank', hue = 'Ceo-female', data = df)
plt.title("Female CEO's by industry")
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.barplot(y ='Revenues', x = 'Hqstate', hue = 'Ceo-female', data = df, ci=None)
plt.title("Female CEO's by industry")
plt.xticks(rotation=270)
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.scatterplot(y ='Profits', x = 'Rank', hue = 'Ceo-female', data = df)
plt.title("Profits by rank")
plt.show()

# %%
or i in range (1,20):
    clf = MLPRegressor(hidden_layer_sizes=(i*10), max_iter=2000, random_state = 0)
    clf.fit(X7_train,Y7_train)
    predictions7 = clf.predict(X7_test)
    scores = cross_val_score(clf, X7_test, Y7_test, cv=6, scoring = 'neg_root_mean_squared_error')
    mae = metrics.mean_absolute_error(Y7_test, predictions7)
    mse = metrics.mean_squared_error(Y7_test, predictions7)
    r2 = metrics.r2_score(Y7_test, predictions7)
    print('-----------------------------------------------')
    print((i*10), 'Hidden layers')
    print('-----------------------------------------------')
    print(f"Negative root mean squared error: mean: {scores.mean()} standard deviation: {scores.std()}")
    print('-----------------------------------------------')
    print('R2 score = ',(r2))
    print('-----------------------------------------------')
    print('Mean absolute error = ',(mae))
    print('-----------------------------------------------')
    print('Mean squared error = ',(mse))
    print('-----------------------------------------------')
    plt.scatter(Y7_test, predictions7)
    plt.plot([0,10000,25000],[0, 10000,25000], color = 'g', linestyle='dashed', label= "Line to show where predicted profits equal actual profits")
    plt.title('True profits value compared to predicted profits value')
    plt.xlabel('True profits value')
    plt.ylabel('Predicted profits value')
    plt.show()
    plt.hist(Y7_test - predictions7)
    plt.title('Frequency of occurence of diffferent values of the difference between true and predicted profit values.')
    plt.xlabel('Difference between true profit values and predicted profit values')
    plt.ylabel('Frequency')
    plt.show()

# %%
for i in range (1,20):
    clf = MLPRegressor(hidden_layer_sizes=(i*10), max_iter=2000, random_state = 0)
    clf.fit(X8_train,Y8_train)
    predictions8 = clf.predict(X8_test)
    scores = cross_val_score(clf, X8_test, Y8_test, cv=6)
    mae = metrics.mean_absolute_error(Y8_test, predictions8)
    mse = metrics.mean_squared_error(Y8_test, predictions8)
    r2 = metrics.r2_score(Y8_test, predictions8)
    print('-----------------------------------------------')
    print((i*10), 'Hidden layers')
    print('-----------------------------------------------')
    print(f"Accuracy: mean: {scores.mean()} standard deviation: {scores.std()}")
    print('-----------------------------------------------')
    print('R2 score = ',(r2))
    print('-----------------------------------------------')
    print('Mean absolute error = ',(mae))
    print('-----------------------------------------------')
    print('Mean squared error = ',(mse))
    print('-----------------------------------------------')
    plt.scatter(Y8_test, predictions8)
    plt.plot([-1,1,6],[-1, 1,6], color = 'g', linestyle='dashed', label= "Line to show where predicted profits equal actual profits")
    plt.title('True profits value compared to predicted profits value')
    plt.xlabel('True profits value')
    plt.ylabel('Predicted profits value')
    plt.show()
    plt.hist(Y8_test - predictions8)
    plt.title('Frequency of occurence of diffferent values of the difference between true and predicted profit values.')
    plt.xlabel('Difference between true profit values and predicted profit values')
    plt.ylabel('Frequency')
    plt.show()

# %%
## Section 1 <a class="anchor" id="section1"></a>
This is Section number 1
### Outliers <a class="anchor" id="outliers"></a>
This is section 1.1
### Section 1.1 <a class="anchor" id="corelation"></a>
This is sub section 1.2
## Section 2 <a class="anchor" id="section2"></a>
This is section number 2
###  Model 1.1  <a class="anchor" id="model1.1"></a>
This is Model 1.1
### Model 1.2 <a class="anchor" id="model1.2"></a>
This is Model 1.2
### Model 1.3 <a class="anchor" id="model1.3"></a>
This is Model 1.3
### Model 1.4 <a class="anchor" id="model1.4"></a>
This is Model 1.4
### Model 1.5 <a class="anchor" id="model1.5"></a>
This is Model 1.5
### Model 1.6 <a class="anchor" id="mdoel1.6"></a>
This is Model 1.6
### Model 1.7 <a class="anchor" id="mdoel1.7"></a>
This is Model 1.7
### Model 1.6 <a class="anchor" id="mdoel1.8"></a>
This is Model 1.7
## Section 3 <a class="anchor" id="chapter3"></a>
